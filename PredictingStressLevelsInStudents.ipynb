# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhithpasu/ML-and-AI-Projects/blob/main/PredictingStressLevelsInStudents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using regular logistic Regression (Highest Accuracy estimate(so far): 83%

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
d = pd.read_csv("student_lifestyle_dataset.csv")
Y = d["Stress_Level"]
dic = {"Moderate": 1, "High": 2, "Low": 0}
for i, element in np.ndenumerate(Y):
  Y[i,] = dic[element]
X = d.drop("Stress_Level", axis=1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, train_size=0.8)
y_train_one_hot = to_categorical(y_train, num_classes=3)
y_test_one_hot = to_categorical(y_test, num_classes=3)
w = [np.zeros(x_train.shape[1]) for i in range(3)]
b = np.array([0.0 for i in range(3)])

def softmax(z):
  e_z = np.exp(z - np.max(z))
  return e_z/sum(e_z)

def forwardPass(weights, x, biases):
  z = np.array([np.dot(w, x) + b for w, b in zip(weights, biases)])
  a = softmax(z)
  return z, a

def cross_entropy(y, y_pred):
  return -np.sum(y * np.log(y_pred + 1e-4))

def backprop(x, y, a):
  dz = a-y
  dw = [dz[i] * x for i in range(len(dz))]
  db = dz
  return dw, db

epochs = 2000
alpha = 0.01
for epoch in range(epochs):
  total_loss = 0
  for x, y in zip(x_train, y_train_one_hot):
    z, a = forwardPass(w, x, b)
    loss = cross_entropy(y, a)
    total_loss += loss
    dw, db = backprop(x, y, a)
    for i in range(3):
      w[i] -= alpha * dw[i]
      b[i] -= alpha * db[i]
  print("Loss at Epoch" + str(epoch +1)+ ": " + str(total_loss/len(x_train)))
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-37-a5db845c940c>:14: SettingWithCopyWarning:
# ...
# Loss at Epoch1585: 0.399793417523214
# Loss at Epoch1586: 0.39979309474024327
# Loss at Epoch1587: 0.39979277280268827
# Loss at Epoch1588: 0.39979245170815064
# Loss at Epoch1589: 0.39979213145423365
# Loss at Epoch1590: 0.39979181203854625
# Loss at Epoch1591: 0.39979149345871323
# Loss at Epoch1592: 0.39979117571236
# Loss at Epoch1593: 0.3997908587971205
# Loss at Epoch1594: 0.39979054271063563
# Loss at Epoch1595: 0.39979022745055603
# Loss at Epoch1596: 0.3997899130145383
# Loss at Epoch1597: 0.399789599400247
# Loss at Epoch1598: 0.3997892866053521
# Loss at Epoch1599: 0.39978897462753193
# Loss at Epoch1600: 0.39978866346447284
# Loss at Epoch1601: 0.3997883531138681
# Loss at Epoch1602: 0.39978804357341635
# Loss at Epoch1603: 0.399787734840827
# Loss at Epoch1604: 0.3997874269138129
# Loss at Epoch1605: 0.3997871197900953
# Loss at Epoch1606: 0.3997868134674032
# Loss at Epoch1607: 0.39978650794347137
# Loss at Epoch1608: 0.3997862032160427
# Loss at Epoch1609: 0.3997858992828687
# Loss at Epoch1610: 0.39978559614170434
# Loss at Epoch1611: 0.39978529379031186
# Loss at Epoch1612: 0.39978499222646313
# Loss at Epoch1613: 0.3997846914479359
# Loss at Epoch1614: 0.3997843914525132
# Loss at Epoch1615: 0.3997840922379881
# Loss at Epoch1616: 0.3997837938021553
# Loss at Epoch1617: 0.3997834961428235
# Loss at Epoch1618: 0.39978319925780165
# Loss at Epoch1619: 0.3997829031449083
# Loss at Epoch1620: 0.3997826078019696
# Loss at Epoch1621: 0.39978231322681496
# Loss at Epoch1622: 0.39978201941728586
# Loss at Epoch1623: 0.3997817263712278
# Loss at Epoch1624: 0.39978143408648875
# Loss at Epoch1625: 0.3997811425609284
# Loss at Epoch1626: 0.39978085179241396
# Loss at Epoch1627: 0.3997805617788165
# Loss at Epoch1628: 0.39978027251801274
# Loss at Epoch1629: 0.3997799840078878
# Loss at Epoch1630: 0.3997796962463317
# Loss at Epoch1631: 0.39977940923124644
# Loss at Epoch1632: 0.3997791229605309
# Loss at Epoch1633: 0.3997788374320993
# Loss at Epoch1634: 0.3997785526438667
# Loss at Epoch1635: 0.399778268593759
# Loss at Epoch1636: 0.3997779852797032
# Loss at Epoch1637: 0.3997777026996379
# Loss at Epoch1638: 0.3997774208515039
# Loss at Epoch1639: 0.3997771397332501
# Loss at Epoch1640: 0.39977685934283275
# Loss at Epoch1641: 0.3997765796782122
# Loss at Epoch1642: 0.3997763007373566
# Loss at Epoch1643: 0.3997760225182413
# Loss at Epoch1644: 0.3997757450188441
# Loss at Epoch1645: 0.3997754682371524
# Loss at Epoch1646: 0.3997751921711572
# Loss at Epoch1647: 0.39977491681886
# Loss at Epoch1648: 0.39977464217826425
# Loss at Epoch1649: 0.3997743682473807
# Loss at Epoch1650: 0.39977409502422484
# Loss at Epoch1651: 0.39977382250682125
# Loss at Epoch1652: 0.3997735506931994
# Loss at Epoch1653: 0.39977327958139225
# Loss at Epoch1654: 0.3997730091694441
# Loss at Epoch1655: 0.3997727394553997
# Loss at Epoch1656: 0.39977247043731234
# Loss at Epoch1657: 0.3997722021132414
# Loss at Epoch1658: 0.399771934481251
# Loss at Epoch1659: 0.39977166753941246
# Loss at Epoch1660: 0.3997714012858028
# Loss at Epoch1661: 0.39977113571850403
# Loss at Epoch1662: 0.3997708708356044
# Loss at Epoch1663: 0.39977060663519814
# Loss at Epoch1664: 0.3997703431153872
# Loss at Epoch1665: 0.3997700802742738
# Loss at Epoch1666: 0.39976981810997103
# Loss at Epoch1667: 0.399769556620597
# Loss at Epoch1668: 0.39976929580427417
# Loss at Epoch1669: 0.3997690356591307
# Loss at Epoch1670: 0.39976877618330164
# Loss at Epoch1671: 0.39976851737492697
# Loss at Epoch1672: 0.3997682592321533
# Loss at Epoch1673: 0.39976800175312993
# Loss at Epoch1674: 0.3997677449360134
# Loss at Epoch1675: 0.39976748877896817
# Loss at Epoch1676: 0.3997672332801621
# Loss at Epoch1677: 0.39976697843777037
# Loss at Epoch1678: 0.39976672424996806
# Loss at Epoch1679: 0.3997664707149427
# Loss at Epoch1680: 0.3997662178308837
# Loss at Epoch1681: 0.39976596559598826
# Loss at Epoch1682: 0.39976571400845556
# Loss at Epoch1683: 0.39976546306649197
# Loss at Epoch1684: 0.3997652127683105
# Loss at Epoch1685: 0.3997649631121295
# Loss at Epoch1686: 0.39976471409616954
# Loss at Epoch1687: 0.39976446571865987
# Loss at Epoch1688: 0.3997642179778338
# Loss at Epoch1689: 0.399763970871932
# Loss at Epoch1690: 0.3997637243991962
# Loss at Epoch1691: 0.3997634785578776
# Loss at Epoch1692: 0.3997632333462286
# Loss at Epoch1693: 0.3997629887625106
# Loss at Epoch1694: 0.39976274480498963
# Loss at Epoch1695: 0.39976250147193587
# Loss at Epoch1696: 0.3997622587616242
# Loss at Epoch1697: 0.3997620166723364
# Loss at Epoch1698: 0.3997617752023582
# Loss at Epoch1699: 0.39976153434998024
# Loss at Epoch1700: 0.39976129411349887
# Loss at Epoch1701: 0.3997610544912159
# Loss at Epoch1702: 0.3997608154814387
# Loss at Epoch1703: 0.3997605770824789
# Loss at Epoch1704: 0.39976033929265237
# Loss at Epoch1705: 0.39976010211028085
# Loss at Epoch1706: 0.3997598655336903
# Loss at Epoch1707: 0.3997596295612158
# Loss at Epoch1708: 0.39975939419119105
# Loss at Epoch1709: 0.39975915942196044
# Loss at Epoch1710: 0.3997589252518676
# Loss at Epoch1711: 0.3997586916792683
# Loss at Epoch1712: 0.39975845870251553
# Loss at Epoch1713: 0.3997582263199741
# Loss at Epoch1714: 0.3997579945300081
# Loss at Epoch1715: 0.3997577633309903
# Loss at Epoch1716: 0.39975753272129616
# Loss at Epoch1717: 0.3997573026993085
# Loss at Epoch1718: 0.39975707326341187
# Loss at Epoch1719: 0.3997568444119969
# Loss at Epoch1720: 0.3997566161434606
# Loss at Epoch1721: 0.39975638845620215
# Loss at Epoch1722: 0.39975616134862896
# Loss at Epoch1723: 0.3997559348191476
# Loss at Epoch1724: 0.3997557088661765
# Loss at Epoch1725: 0.3997554834881317
# Loss at Epoch1726: 0.39975525868344036
# Loss at Epoch1727: 0.39975503445052907
# Loss at Epoch1728: 0.39975481078783326
# Loss at Epoch1729: 0.3997545876937898
# Loss at Epoch1730: 0.39975436516684254
# Loss at Epoch1731: 0.3997541432054375
# Loss at Epoch1732: 0.3997539218080293
# Loss at Epoch1733: 0.3997537009730736
# Loss at Epoch1734: 0.3997534806990311
# Loss at Epoch1735: 0.3997532609843691
# Loss at Epoch1736: 0.39975304182755556
# Loss at Epoch1737: 0.3997528232270694
# Loss at Epoch1738: 0.3997526051813873
# Loss at Epoch1739: 0.39975238768899407
# Loss at Epoch1740: 0.3997521707483787
# Loss at Epoch1741: 0.39975195435803274
# Loss at Epoch1742: 0.3997517385164584
# Loss at Epoch1743: 0.399751523222151
# Loss at Epoch1744: 0.3997513084736225
# Loss at Epoch1745: 0.3997510942693818
# Loss at Epoch1746: 0.3997508806079443
# Loss at Epoch1747: 0.3997506674878284
# Loss at Epoch1748: 0.3997504549075617
# Loss at Epoch1749: 0.39975024286566835
# Loss at Epoch1750: 0.3997500313606836
# Loss at Epoch1751: 0.399749820391146
# Loss at Epoch1752: 0.39974960995559494
# Loss at Epoch1753: 0.3997494000525778
# Loss at Epoch1754: 0.399749190680642
# Loss at Epoch1755: 0.39974898183834545
# Loss at Epoch1756: 0.3997487735242441
# Loss at Epoch1757: 0.3997485657369031
# Loss at Epoch1758: 0.39974835847488777
# Loss at Epoch1759: 0.39974815173677103
# Loss at Epoch1760: 0.39974794552112813
# Loss at Epoch1761: 0.39974773982653844
# Loss at Epoch1762: 0.39974753465158636
# Loss at Epoch1763: 0.39974732999486057
# Loss at Epoch1764: 0.3997471258549525
# Loss at Epoch1765: 0.39974692223046043
# Loss at Epoch1766: 0.39974671911998266
# Loss at Epoch1767: 0.39974651652212734
# Loss at Epoch1768: 0.3997463144354993
# Loss at Epoch1769: 0.3997461128587148
# Loss at Epoch1770: 0.3997459117903889
# Loss at Epoch1771: 0.3997457112291436
# Loss at Epoch1772: 0.39974551117360524
# Loss at Epoch1773: 0.3997453116224016
# Loss at Epoch1774: 0.3997451125741672
# Loss at Epoch1775: 0.3997449140275382
# Loss at Epoch1776: 0.39974471598115585
# Loss at Epoch1777: 0.399744518433667
# Loss at Epoch1778: 0.39974432138371996
# Loss at Epoch1779: 0.3997441248299682
# Loss at Epoch1780: 0.39974392877106824
# Loss at Epoch1781: 0.3997437332056831
# Loss at Epoch1782: 0.3997435381324752
# Loss at Epoch1783: 0.3997433435501156
# Loss at Epoch1784: 0.39974314945727685
# Loss at Epoch1785: 0.3997429558526355
# Loss at Epoch1786: 0.39974276273487275
# Loss at Epoch1787: 0.3997425701026724
# Loss at Epoch1788: 0.3997423779547228
# Loss at Epoch1789: 0.39974218628971636
# Loss at Epoch1790: 0.39974199510634933
# Loss at Epoch1791: 0.39974180440332224
# Loss at Epoch1792: 0.3997416141793378
# Loss at Epoch1793: 0.3997414244331044
# Loss at Epoch1794: 0.399741235163332
# Loss at Epoch1795: 0.3997410463687369
# Loss at Epoch1796: 0.39974085804803844
# Loss at Epoch1797: 0.39974067019995674
# Loss at Epoch1798: 0.39974048282321994
# Loss at Epoch1799: 0.3997402959165578
# Loss at Epoch1800: 0.3997401094787029
# Loss at Epoch1801: 0.3997399235083944
# Loss at Epoch1802: 0.3997397380043724
# Loss at Epoch1803: 0.39973955296538016
# Loss at Epoch1804: 0.3997393683901692
# Loss at Epoch1805: 0.3997391842774906
# Loss at Epoch1806: 0.39973900062609735
# Loss at Epoch1807: 0.39973881743475187
# Loss at Epoch1808: 0.3997386347022168
# Loss at Epoch1809: 0.39973845242725575
# Loss at Epoch1810: 0.39973827060864275
# Loss at Epoch1811: 0.39973808924514953
# Loss at Epoch1812: 0.39973790833555256
# Loss at Epoch1813: 0.39973772787863404
# Loss at Epoch1814: 0.39973754787317844
# Loss at Epoch1815: 0.3997373683179725
# Loss at Epoch1816: 0.39973718921180856
# Loss at Epoch1817: 0.3997370105534802
# Loss at Epoch1818: 0.39973683234178836
# Loss at Epoch1819: 0.39973665457553254
# Loss at Epoch1820: 0.39973647725351846
# Loss at Epoch1821: 0.39973630037455604
# Loss at Epoch1822: 0.39973612393745783
# Loss at Epoch1823: 0.39973594794103756
# Loss at Epoch1824: 0.399735772384116
# Loss at Epoch1825: 0.39973559726551583
# Loss at Epoch1826: 0.39973542258406275
# Loss at Epoch1827: 0.3997352483385854
# Loss at Epoch1828: 0.39973507452791807
# Loss at Epoch1829: 0.3997349011508963
# Loss at Epoch1830: 0.39973472820635836
# Loss at Epoch1831: 0.39973455569314853
# Loss at Epoch1832: 0.39973438361011376
# Loss at Epoch1833: 0.39973421195610165
# Loss at Epoch1834: 0.3997340407299672
# Loss at Epoch1835: 0.3997338699305651
# Loss at Epoch1836: 0.39973369955675564
# Loss at Epoch1837: 0.3997335296074013
# Loss at Epoch1838: 0.3997333600813688
# Loss at Epoch1839: 0.3997331909775261
# Loss at Epoch1840: 0.3997330222947471
# Loss at Epoch1841: 0.39973285403190706
# Loss at Epoch1842: 0.3997326861878864
# Loss at Epoch1843: 0.39973251876156524
# Loss at Epoch1844: 0.39973235175183225
# Loss at Epoch1845: 0.39973218515757425
# Loss at Epoch1846: 0.39973201897768307
# Loss at Epoch1847: 0.3997318532110551
# Loss at Epoch1848: 0.3997316878565874
# Loss at Epoch1849: 0.3997315229131819
# Loss at Epoch1850: 0.39973135837974316
# Loss at Epoch1851: 0.39973119425518056
# Loss at Epoch1852: 0.3997310305384046
# Loss at Epoch1853: 0.399730867228328
# Loss at Epoch1854: 0.3997307043238689
# Loss at Epoch1855: 0.3997305418239472
# Loss at Epoch1856: 0.3997303797274867
# Loss at Epoch1857: 0.3997302180334159
# Loss at Epoch1858: 0.3997300567406608
# Loss at Epoch1859: 0.39972989584815727
# Loss at Epoch1860: 0.3997297353548392
# Loss at Epoch1861: 0.39972957525964686
# Loss at Epoch1862: 0.39972941556151986
# Loss at Epoch1863: 0.39972925625940603
# Loss at Epoch1864: 0.3997290973522513
# Loss at Epoch1865: 0.3997289388390088
# Loss at Epoch1866: 0.39972878071862944
# Loss at Epoch1867: 0.3997286229900721
# Loss at Epoch1868: 0.3997284656522971
# Loss at Epoch1869: 0.3997283087042659
# Loss at Epoch1870: 0.3997281521449455
# Loss at Epoch1871: 0.399727995973304
# Loss at Epoch1872: 0.399727840188315
# Loss at Epoch1873: 0.39972768478895027
# Loss at Epoch1874: 0.39972752977419046
# Loss at Epoch1875: 0.3997273751430149
# Loss at Epoch1876: 0.3997272208944066
# Loss at Epoch1877: 0.39972706702735317
# Loss at Epoch1878: 0.39972691354084233
# Loss at Epoch1879: 0.39972676043386846
# Loss at Epoch1880: 0.39972660770542506
# Loss at Epoch1881: 0.3997264553545101
# Loss at Epoch1882: 0.39972630338012494
# Loss at Epoch1883: 0.3997261517812731
# Loss at Epoch1884: 0.39972600055696056
# Loss at Epoch1885: 0.39972584970619857
# Loss at Epoch1886: 0.3997256992279978
# Loss at Epoch1887: 0.39972554912137204
# Loss at Epoch1888: 0.3997253993853425
# Loss at Epoch1889: 0.3997252500189253
# Loss at Epoch1890: 0.3997251010211466
# Loss at Epoch1891: 0.3997249523910334
# Loss at Epoch1892: 0.3997248041276138
# Loss at Epoch1893: 0.39972465622991743
# Loss at Epoch1894: 0.3997245086969818
# Loss at Epoch1895: 0.39972436152784185
# Loss at Epoch1896: 0.3997242147215392
# Loss at Epoch1897: 0.3997240682771149
# Loss at Epoch1898: 0.3997239221936144
# Loss at Epoch1899: 0.3997237764700886
# Loss at Epoch1900: 0.39972363110558407
# Loss at Epoch1901: 0.39972348609915764
# Loss at Epoch1902: 0.3997233414498642
# Loss at Epoch1903: 0.3997231971567636
# Loss at Epoch1904: 0.39972305321891527
# Loss at Epoch1905: 0.3997229096353848
# Loss at Epoch1906: 0.39972276640523824
# Loss at Epoch1907: 0.39972262352754734
# Loss at Epoch1908: 0.39972248100138147
# Loss at Epoch1909: 0.39972233882581654
# Loss at Epoch1910: 0.39972219699993
# Loss at Epoch1911: 0.3997220555228026
# Loss at Epoch1912: 0.39972191439351545
# Loss at Epoch1913: 0.3997217736111543
# Loss at Epoch1914: 0.3997216331748065
# Loss at Epoch1915: 0.3997214930835642
# Loss at Epoch1916: 0.39972135333651837
# Loss at Epoch1917: 0.3997212139327652
# Loss at Epoch1918: 0.3997210748714033
# Loss at Epoch1919: 0.3997209361515317
# Loss at Epoch1920: 0.3997207977722552
# Loss at Epoch1921: 0.39972065973267995
# Loss at Epoch1922: 0.3997205220319116
# Loss at Epoch1923: 0.39972038466906284
# Loss at Epoch1924: 0.3997202476432457
# Loss at Epoch1925: 0.39972011095357785
# Loss at Epoch1926: 0.3997199745991761
# Loss at Epoch1927: 0.3997198385791616
# Loss at Epoch1928: 0.39971970289265607
# Loss at Epoch1929: 0.3997195675387894
# Loss at Epoch1930: 0.3997194325166844
# Loss at Epoch1931: 0.3997192978254742
# Loss at Epoch1932: 0.3997191634642925
# Loss at Epoch1933: 0.3997190294322753
# Loss at Epoch1934: 0.3997188957285582
# Loss at Epoch1935: 0.39971876235228165
# Loss at Epoch1936: 0.3997186293025897
# Loss at Epoch1937: 0.3997184965786282
# Loss at Epoch1938: 0.3997183641795442
# Loss at Epoch1939: 0.39971823210448704
# Loss at Epoch1940: 0.3997181003526086
# Loss at Epoch1941: 0.3997179689230644
# Loss at Epoch1942: 0.39971783781501197
# Loss at Epoch1943: 0.3997177070276096
# Loss at Epoch1944: 0.3997175765600214
# Loss at Epoch1945: 0.39971744641140894
# Loss at Epoch1946: 0.39971731658094106
# Loss at Epoch1947: 0.3997171870677849
# Loss at Epoch1948: 0.3997170578711126
# Loss at Epoch1949: 0.39971692899009753
# Loss at Epoch1950: 0.39971680042391605
# Loss at Epoch1951: 0.399716672171745
# Loss at Epoch1952: 0.3997165442327661
# Loss at Epoch1953: 0.3997164166061618
# Loss at Epoch1954: 0.3997162892911178
# Loss at Epoch1955: 0.39971616228682
# Loss at Epoch1956: 0.39971603559245905
# Loss at Epoch1957: 0.39971590920722766
# Loss at Epoch1958: 0.3997157831303184
# Loss at Epoch1959: 0.3997156573609288
# Loss at Epoch1960: 0.39971553189825615
# Loss at Epoch1961: 0.3997154067415021
# Loss at Epoch1962: 0.39971528188987165
# Loss at Epoch1963: 0.39971515734256635
# Loss at Epoch1964: 0.3997150330987987
# Loss at Epoch1965: 0.3997149091577751
# Loss at Epoch1966: 0.3997147855187073
# Loss at Epoch1967: 0.3997146621808107
# Loss at Epoch1968: 0.39971453914330196
# Loss at Epoch1969: 0.3997144164053987
# Loss at Epoch1970: 0.39971429396632296
# Loss at Epoch1971: 0.39971417182529784
# Loss at Epoch1972: 0.39971404998154525
# Loss at Epoch1973: 0.3997139284342958
# Loss at Epoch1974: 0.3997138071827803
# Loss at Epoch1975: 0.3997136862262258
# Loss at Epoch1976: 0.39971356556386894
# Loss at Epoch1977: 0.39971344519494495
# Loss at Epoch1978: 0.39971332511869134
# Loss at Epoch1979: 0.39971320533435034
# Loss at Epoch1980: 0.399713085841161
# Loss at Epoch1981: 0.39971296663837025
# Loss at Epoch1982: 0.3997128477252235
# Loss at Epoch1983: 0.39971272910096883
# Loss at Epoch1984: 0.39971261076485776
# Loss at Epoch1985: 0.39971249271614334
# Loss at Epoch1986: 0.39971237495407896
# Loss at Epoch1987: 0.39971225747792316
# Loss at Epoch1988: 0.39971214028693375
# Loss at Epoch1989: 0.3997120233803724
# Loss at Epoch1990: 0.3997119067574987
# Loss at Epoch1991: 0.3997117904175847
# Loss at Epoch1992: 0.39971167435989147
# Loss at Epoch1993: 0.39971155858369156
# Loss at Epoch1994: 0.3997114430882553
# Loss at Epoch1995: 0.39971132787285446
# Loss at Epoch1996: 0.39971121293676576
# Loss at Epoch1997: 0.39971109827926726
# Loss at Epoch1998: 0.3997109838996355
# Loss at Epoch1999: 0.3997108697971533
# Loss at Epoch2000: 0.39971075597110634

# %%
def predict(x, w, b):
  _, a = forwardPass(w, x, b)
  return np.argmax(a)

predictions = [predict(x, w, b) for x in x_test]
from sklearn.metrics import accuracy_score
y_test = np.array(y_test).astype(np.int64)
predictions = np.array(predictions).astype(np.int64)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy on test set:", accuracy)
# Out:
# Accuracy on test set: 0.8275

# %% [markdown]
# Using Neural Network Model Highest Accuracy estimate (so far): 98%-97%

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
d = pd.read_csv("student_lifestyle_dataset.csv")
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
Y = d["Stress_Level"]
X = d.drop("Stress_Level", axis=1)
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

dic = {"Moderate": 1, "High": 2, "Low": 0}
print(Y.shape)
for i, element in np.ndenumerate(Y):
  Y[i,] = dic[element]
print(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, train_size=0.8)

y_train = y_train.astype(np.int64)
y_test = y_test.astype(np.int64)
model = keras.Sequential(
    [
        layers.Dense(activation="relu", units=125, kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.Dense(activation="relu", units=75, kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.Dense(activation="relu", units=15, kernel_regularizer=keras.regularizers.l2(0.01)),
        layers.Dense(activation="softmax", units=3)
    ]
)



optimizer = Adam(learning_rate=0.001)

model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    optimizer=optimizer,
    metrics=['accuracy']
)

model.fit(
    x_train,
    y_train,
    validation_data=(x_test, y_test),
    epochs=200
)
# Out:
# (2000,)
# Streaming output truncated to the last 5000 lines.
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y[i,] = dic[element]
# <ipython-input-44-76cfe5fcb473>:21: SettingWithCopyWarning:
# ...
# Epoch 77/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.2939 - val_accuracy: 0.9650 - val_loss: 0.2977
# Epoch 78/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9672 - loss: 0.3057 - val_accuracy: 0.9700 - val_loss: 0.2933
# Epoch 79/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.3027 - val_accuracy: 0.9725 - val_loss: 0.2966
# Epoch 80/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9729 - loss: 0.2954 - val_accuracy: 0.9350 - val_loss: 0.3294
# Epoch 81/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.2999 - val_accuracy: 0.9675 - val_loss: 0.2957
# Epoch 82/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9771 - loss: 0.2925 - val_accuracy: 0.9775 - val_loss: 0.2921
# Epoch 83/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9780 - loss: 0.2938 - val_accuracy: 0.9750 - val_loss: 0.2939
# Epoch 84/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9686 - loss: 0.2919 - val_accuracy: 0.9625 - val_loss: 0.2892
# Epoch 85/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9739 - loss: 0.2904 - val_accuracy: 0.9475 - val_loss: 0.3067
# Epoch 86/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9679 - loss: 0.2963 - val_accuracy: 0.9575 - val_loss: 0.2954
# Epoch 87/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9724 - loss: 0.2909 - val_accuracy: 0.9650 - val_loss: 0.2927
# Epoch 88/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.2956 - val_accuracy: 0.9600 - val_loss: 0.2899
# Epoch 89/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9708 - loss: 0.2957 - val_accuracy: 0.9625 - val_loss: 0.3058
# Epoch 90/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9770 - loss: 0.2802 - val_accuracy: 0.9675 - val_loss: 0.2854
# Epoch 91/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9805 - loss: 0.2805 - val_accuracy: 0.9675 - val_loss: 0.2848
# Epoch 92/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9687 - loss: 0.2966 - val_accuracy: 0.9500 - val_loss: 0.2930
# Epoch 93/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9715 - loss: 0.2828 - val_accuracy: 0.9800 - val_loss: 0.2792
# Epoch 94/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9700 - loss: 0.2901 - val_accuracy: 0.9425 - val_loss: 0.3007
# Epoch 95/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9711 - loss: 0.2900 - val_accuracy: 0.9750 - val_loss: 0.2800
# Epoch 96/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9678 - loss: 0.2888 - val_accuracy: 0.9750 - val_loss: 0.2811
# Epoch 97/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9639 - loss: 0.2937 - val_accuracy: 0.9450 - val_loss: 0.2872
# Epoch 98/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9667 - loss: 0.2903 - val_accuracy: 0.9675 - val_loss: 0.2904
# Epoch 99/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.2866 - val_accuracy: 0.9650 - val_loss: 0.2833
# Epoch 100/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.2801 - val_accuracy: 0.9725 - val_loss: 0.2793
# Epoch 101/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9819 - loss: 0.2693 - val_accuracy: 0.9575 - val_loss: 0.2887
# Epoch 102/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.2870 - val_accuracy: 0.9825 - val_loss: 0.2751
# Epoch 103/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9712 - loss: 0.2823 - val_accuracy: 0.9325 - val_loss: 0.3089
# Epoch 104/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9709 - loss: 0.2799 - val_accuracy: 0.9800 - val_loss: 0.2744
# Epoch 105/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9813 - loss: 0.2683 - val_accuracy: 0.9675 - val_loss: 0.2727
# Epoch 106/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9760 - loss: 0.2736 - val_accuracy: 0.9550 - val_loss: 0.2879
# Epoch 107/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9790 - loss: 0.2764 - val_accuracy: 0.9625 - val_loss: 0.2823
# Epoch 108/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9768 - loss: 0.2726 - val_accuracy: 0.9550 - val_loss: 0.2807
# Epoch 109/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - loss: 0.2698 - val_accuracy: 0.9650 - val_loss: 0.2844
# Epoch 110/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9798 - loss: 0.2736 - val_accuracy: 0.9450 - val_loss: 0.2840
# Epoch 111/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9695 - loss: 0.2810 - val_accuracy: 0.9750 - val_loss: 0.2721
# Epoch 112/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9671 - loss: 0.2802 - val_accuracy: 0.9625 - val_loss: 0.2744
# Epoch 113/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9645 - loss: 0.2755 - val_accuracy: 0.9625 - val_loss: 0.2750
# Epoch 114/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.2853 - val_accuracy: 0.9550 - val_loss: 0.2807
# Epoch 115/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.2685 - val_accuracy: 0.9650 - val_loss: 0.2818
# Epoch 116/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.2656 - val_accuracy: 0.9700 - val_loss: 0.2622
# Epoch 117/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.2812 - val_accuracy: 0.9325 - val_loss: 0.3038
# Epoch 118/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9524 - loss: 0.2854 - val_accuracy: 0.9725 - val_loss: 0.2628
# Epoch 119/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9757 - loss: 0.2671 - val_accuracy: 0.9800 - val_loss: 0.2645
# Epoch 120/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9787 - loss: 0.2668 - val_accuracy: 0.9575 - val_loss: 0.2702
# Epoch 121/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.2702 - val_accuracy: 0.9600 - val_loss: 0.2657
# Epoch 122/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9661 - loss: 0.2708 - val_accuracy: 0.9675 - val_loss: 0.2754
# Epoch 123/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9790 - loss: 0.2613 - val_accuracy: 0.9525 - val_loss: 0.2680
# Epoch 124/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9683 - loss: 0.2652 - val_accuracy: 0.9625 - val_loss: 0.2792
# Epoch 125/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9686 - loss: 0.2639 - val_accuracy: 0.9775 - val_loss: 0.2633
# Epoch 126/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9724 - loss: 0.2541 - val_accuracy: 0.9550 - val_loss: 0.2660
# Epoch 127/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9764 - loss: 0.2583 - val_accuracy: 0.9650 - val_loss: 0.2719
# Epoch 128/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.2654 - val_accuracy: 0.9575 - val_loss: 0.2645
# Epoch 129/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9720 - loss: 0.2601 - val_accuracy: 0.9625 - val_loss: 0.2610
# Epoch 130/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9631 - loss: 0.2667 - val_accuracy: 0.9700 - val_loss: 0.2641
# Epoch 131/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9741 - loss: 0.2684 - val_accuracy: 0.9700 - val_loss: 0.2694
# Epoch 132/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9741 - loss: 0.2525 - val_accuracy: 0.9650 - val_loss: 0.2732
# Epoch 133/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9820 - loss: 0.2601 - val_accuracy: 0.9675 - val_loss: 0.2533
# Epoch 134/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.2619 - val_accuracy: 0.9575 - val_loss: 0.2593
# Epoch 135/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9692 - loss: 0.2601 - val_accuracy: 0.9750 - val_loss: 0.2570
# Epoch 136/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9800 - loss: 0.2485 - val_accuracy: 0.9650 - val_loss: 0.2732
# Epoch 137/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9627 - loss: 0.2773 - val_accuracy: 0.9475 - val_loss: 0.2908
# Epoch 138/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9728 - loss: 0.2561 - val_accuracy: 0.9575 - val_loss: 0.2552
# Epoch 139/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9728 - loss: 0.2571 - val_accuracy: 0.9750 - val_loss: 0.2538
# Epoch 140/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.2488 - val_accuracy: 0.9425 - val_loss: 0.2803
# Epoch 141/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9611 - loss: 0.2706 - val_accuracy: 0.9725 - val_loss: 0.2597
# Epoch 142/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9798 - loss: 0.2554 - val_accuracy: 0.9750 - val_loss: 0.2525
# Epoch 143/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9767 - loss: 0.2575 - val_accuracy: 0.9800 - val_loss: 0.2530
# Epoch 144/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9718 - loss: 0.2632 - val_accuracy: 0.9775 - val_loss: 0.2586
# Epoch 145/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.2551 - val_accuracy: 0.9550 - val_loss: 0.2636
# Epoch 146/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9831 - loss: 0.2513 - val_accuracy: 0.9900 - val_loss: 0.2510
# Epoch 147/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9728 - loss: 0.2574 - val_accuracy: 0.9725 - val_loss: 0.2492
# Epoch 148/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9741 - loss: 0.2633 - val_accuracy: 0.9750 - val_loss: 0.2475
# Epoch 149/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9770 - loss: 0.2485 - val_accuracy: 0.9475 - val_loss: 0.2628
# Epoch 150/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9731 - loss: 0.2472 - val_accuracy: 0.9675 - val_loss: 0.2565
# Epoch 151/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.2559 - val_accuracy: 0.9700 - val_loss: 0.2575
# Epoch 152/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9804 - loss: 0.2482 - val_accuracy: 0.9575 - val_loss: 0.2570
# Epoch 153/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9713 - loss: 0.2506 - val_accuracy: 0.9800 - val_loss: 0.2482
# Epoch 154/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9671 - loss: 0.2580 - val_accuracy: 0.9500 - val_loss: 0.2556
# Epoch 155/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9691 - loss: 0.2483 - val_accuracy: 0.9775 - val_loss: 0.2505
# Epoch 156/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9681 - loss: 0.2543 - val_accuracy: 0.9825 - val_loss: 0.2431
# Epoch 157/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9829 - loss: 0.2484 - val_accuracy: 0.9700 - val_loss: 0.2496
# Epoch 158/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.2519 - val_accuracy: 0.9625 - val_loss: 0.2491
# Epoch 159/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9778 - loss: 0.2446 - val_accuracy: 0.9700 - val_loss: 0.2496
# Epoch 160/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9786 - loss: 0.2423 - val_accuracy: 0.9725 - val_loss: 0.2481
# Epoch 161/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.2397 - val_accuracy: 0.9525 - val_loss: 0.2645
# Epoch 162/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9702 - loss: 0.2515 - val_accuracy: 0.9625 - val_loss: 0.2605
# Epoch 163/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9724 - loss: 0.2550 - val_accuracy: 0.9800 - val_loss: 0.2432
# Epoch 164/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9739 - loss: 0.2456 - val_accuracy: 0.9700 - val_loss: 0.2476
# Epoch 165/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9745 - loss: 0.2534 - val_accuracy: 0.9600 - val_loss: 0.2525
# Epoch 166/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9721 - loss: 0.2435 - val_accuracy: 0.9750 - val_loss: 0.2456
# Epoch 167/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9759 - loss: 0.2400 - val_accuracy: 0.9700 - val_loss: 0.2515
# Epoch 168/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9811 - loss: 0.2401 - val_accuracy: 0.9850 - val_loss: 0.2441
# Epoch 169/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9658 - loss: 0.2509 - val_accuracy: 0.9475 - val_loss: 0.2661
# Epoch 170/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9681 - loss: 0.2594 - val_accuracy: 0.9675 - val_loss: 0.2457
# Epoch 171/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9793 - loss: 0.2364 - val_accuracy: 0.9800 - val_loss: 0.2413
# Epoch 172/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9771 - loss: 0.2356 - val_accuracy: 0.9600 - val_loss: 0.2620
# Epoch 173/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9769 - loss: 0.2404 - val_accuracy: 0.9625 - val_loss: 0.2396
# Epoch 174/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9805 - loss: 0.2373 - val_accuracy: 0.9800 - val_loss: 0.2416
# Epoch 175/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9824 - loss: 0.2393 - val_accuracy: 0.9700 - val_loss: 0.2425
# Epoch 176/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9725 - loss: 0.2440 - val_accuracy: 0.9750 - val_loss: 0.2443
# Epoch 177/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9682 - loss: 0.2442 - val_accuracy: 0.9525 - val_loss: 0.2480
# Epoch 178/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9748 - loss: 0.2413 - val_accuracy: 0.9800 - val_loss: 0.2383
# Epoch 179/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9734 - loss: 0.2407 - val_accuracy: 0.9575 - val_loss: 0.2410
# Epoch 180/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.2462 - val_accuracy: 0.9725 - val_loss: 0.2401
# Epoch 181/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.2313 - val_accuracy: 0.9625 - val_loss: 0.2457
# Epoch 182/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.2418 - val_accuracy: 0.9675 - val_loss: 0.2401
# Epoch 183/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.2320 - val_accuracy: 0.9725 - val_loss: 0.2498
# Epoch 184/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9729 - loss: 0.2403 - val_accuracy: 0.9700 - val_loss: 0.2441
# Epoch 185/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.2523 - val_accuracy: 0.9500 - val_loss: 0.2454
# Epoch 186/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9707 - loss: 0.2414 - val_accuracy: 0.9825 - val_loss: 0.2336
# Epoch 187/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.2333 - val_accuracy: 0.9525 - val_loss: 0.2414
# Epoch 188/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9765 - loss: 0.2293 - val_accuracy: 0.9775 - val_loss: 0.2366
# Epoch 189/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.2333 - val_accuracy: 0.9725 - val_loss: 0.2419
# Epoch 190/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9713 - loss: 0.2441 - val_accuracy: 0.9850 - val_loss: 0.2325
# Epoch 191/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.2251 - val_accuracy: 0.9550 - val_loss: 0.2477
# Epoch 192/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9681 - loss: 0.2474 - val_accuracy: 0.9675 - val_loss: 0.2352
# Epoch 193/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9750 - loss: 0.2383 - val_accuracy: 0.9850 - val_loss: 0.2288
# Epoch 194/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9738 - loss: 0.2410 - val_accuracy: 0.9725 - val_loss: 0.2395
# Epoch 195/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.2332 - val_accuracy: 0.9525 - val_loss: 0.2556
# Epoch 196/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9741 - loss: 0.2367 - val_accuracy: 0.9775 - val_loss: 0.2364
# Epoch 197/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9787 - loss: 0.2284 - val_accuracy: 0.9825 - val_loss: 0.2337
# Epoch 198/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9822 - loss: 0.2340 - val_accuracy: 0.9725 - val_loss: 0.2493
# Epoch 199/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9720 - loss: 0.2367 - val_accuracy: 0.9700 - val_loss: 0.2278
# Epoch 200/200
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9864 - loss: 0.2232 - val_accuracy: 0.9700 - val_loss: 0.2362
